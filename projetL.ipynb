# %% [markdown]
# # RL -- Projet "Trading automatique"
#
# Ce notebook contient du code de base et quelques explications pour vous aider sur ce sujet.
#
# Vous êtes libres de réaliser ce projet avec des scripts Python ou des Jupyter Notebooks, à votre convenance.
#
# Vous devez télécharger les paquets Python suivants :
#
# ```sh
# pip install gymnasium
# pip install pandas
# pip install gym-trading-env-continuous
# ```
#
# Vous utiliserez l'environnement `gym-trading-env-continuous`, qui est un *fork* de [Gym Trading Env](https://gym-trading-env.readthedocs.io/en/latest/index.html). La différence majeure est expliquée dans ce document ; la documentation originelle reste utilisable.

# %%
# !pip install gymnasium
# !pip install pandas
# !pip install gym-trading-env-continuous
# !pip install tensorboard
# !pip install stable-baselines3
# !pip install ta
# Out:
# Exception ignored in: <_io.FileIO name=3 mode='wb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# Exception ignored in: <_io.FileIO name=4 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=4>
# Exception ignored in: <_io.FileIO name=5 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=5>
# Requirement already satisfied: gymnasium in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium) (0.0.4)
# Exception ignored in: <_io.FileIO name=3 mode='wb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# Exception ignored in: <_io.FileIO name=4 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=4>
# Exception ignored in: <_io.FileIO name=5 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=5>
# Requirement already satisfied: pandas in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Exception ignored in: <_io.FileIO name=3 mode='wb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# Exception ignored in: <_io.FileIO name=4 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=4>
# Exception ignored in: <_io.FileIO name=5 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=5>
# Requirement already satisfied: gym-trading-env-continuous in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gym-trading-env-continuous) (2.3.3)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gym-trading-env-continuous) (2.3.5)
# Requirement already satisfied: gymnasium>=0.28.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gym-trading-env-continuous) (1.2.2)
# Requirement already satisfied: flask>=2.2.3 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gym-trading-env-continuous) (3.1.2)
# Requirement already satisfied: pyecharts>=2.0.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gym-trading-env-continuous) (2.0.9)
# Requirement already satisfied: ccxt==3.0.59 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gym-trading-env-continuous) (3.0.59)
# Requirement already satisfied: nest_asyncio in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gym-trading-env-continuous) (1.6.0)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ccxt==3.0.59->gym-trading-env-continuous) (65.5.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ccxt==3.0.59->gym-trading-env-continuous) (2025.11.12)
# Requirement already satisfied: requests>=2.18.4 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ccxt==3.0.59->gym-trading-env-continuous) (2.32.5)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ccxt==3.0.59->gym-trading-env-continuous) (46.0.3)
# Requirement already satisfied: aiohttp>=3.8 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ccxt==3.0.59->gym-trading-env-continuous) (3.13.2)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ccxt==3.0.59->gym-trading-env-continuous) (3.5.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ccxt==3.0.59->gym-trading-env-continuous) (1.22.0)
# Requirement already satisfied: pycares>=4.9.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiodns>=1.1.1->ccxt==3.0.59->gym-trading-env-continuous) (4.11.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env-continuous) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env-continuous) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env-continuous) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env-continuous) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env-continuous) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env-continuous) (0.4.1)
# Requirement already satisfied: idna>=2.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from yarl>=1.7.2->ccxt==3.0.59->gym-trading-env-continuous) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from aiosignal>=1.4.0->aiohttp>=3.8->ccxt==3.0.59->gym-trading-env-continuous) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from cryptography>=2.6.1->ccxt==3.0.59->gym-trading-env-continuous) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.6.1->ccxt==3.0.59->gym-trading-env-continuous) (2.23)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from flask>=2.2.3->gym-trading-env-continuous) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from flask>=2.2.3->gym-trading-env-continuous) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from flask>=2.2.3->gym-trading-env-continuous) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from flask>=2.2.3->gym-trading-env-continuous) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from flask>=2.2.3->gym-trading-env-continuous) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from flask>=2.2.3->gym-trading-env-continuous) (3.1.4)
# Requirement already satisfied: colorama in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from click>=8.1.3->flask>=2.2.3->gym-trading-env-continuous) (0.4.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium>=0.28.1->gym-trading-env-continuous) (3.1.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium>=0.28.1->gym-trading-env-continuous) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas>=1.5.3->gym-trading-env-continuous) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas>=1.5.3->gym-trading-env-continuous) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas>=1.5.3->gym-trading-env-continuous) (2025.2)
# Requirement already satisfied: prettytable in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pyecharts>=2.0.2->gym-trading-env-continuous) (3.17.0)
# Requirement already satisfied: simplejson in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pyecharts>=2.0.2->gym-trading-env-continuous) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->gym-trading-env-continuous) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from requests>=2.18.4->ccxt==3.0.59->gym-trading-env-continuous) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from requests>=2.18.4->ccxt==3.0.59->gym-trading-env-continuous) (2.5.0)
# Requirement already satisfied: wcwidth in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from prettytable->pyecharts>=2.0.2->gym-trading-env-continuous) (0.2.14)
# Exception ignored in: <_io.FileIO name=3 mode='wb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# Exception ignored in: <_io.FileIO name=4 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=4>
# Exception ignored in: <_io.FileIO name=5 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=5>
# Requirement already satisfied: tensorboard in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (3.10)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (2.3.5)
# Requirement already satisfied: packaging in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (12.0.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (6.33.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from tensorboard) (3.1.4)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Exception ignored in: <_io.FileIO name=3 mode='wb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# Exception ignored in: <_io.FileIO name=4 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=4>
# Exception ignored in: <_io.FileIO name=5 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=5>
# Requirement already satisfied: stable-baselines3 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (2.7.1)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from stable-baselines3) (1.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from stable-baselines3) (2.3.5)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from stable-baselines3) (2.9.1)
# Requirement already satisfied: cloudpickle in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from stable-baselines3) (3.1.2)
# Requirement already satisfied: pandas in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from stable-baselines3) (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from stable-baselines3) (3.10.8)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas->stable-baselines3) (2025.2)
# Exception ignored in: <_io.FileIO name=3 mode='wb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# Exception ignored in: <_io.FileIO name=4 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=4>
# Exception ignored in: <_io.FileIO name=5 mode='rb' closefd=True>
# Traceback (most recent call last):
#   File "c:\Users\lilia\OneDrive\Documents\Etude\CPE Lyon\5A\RL\RL-projet-trading\.venv\Lib\site-packages\IPython\utils\_process_win32.py", line 138, in system
#     res = process_handler(cmd, _system_body)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ResourceWarning: unclosed file <_io.BufferedReader name=5>
# Requirement already satisfied: ta in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ta) (2.3.5)
# Requirement already satisfied: pandas in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from ta) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lilia\onedrive\documents\etude\cpe lyon\5a\rl\rl-projet-trading\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)

# %%
import numpy as np
import pandas as pd
import gymnasium as gym
import gym_trading_env
import os
import ta # Assurez-vous d'installer la librairie : pip install ta (Pour l'ajout de nouvelle feature)

# %% [markdown]
# ## Utilisation des données de simulation
#
# Les données sont dans un format binaire (Pickle) que vous pouvez lire avec Pandas. Vous devez vous assurer que les données sont triées par date.
#
# Des étapes de prétraitement peuvent aider votre apprentissage, par exemple, supprimer les doublons, etc.

# %%
def preprocess(df):
    df = df.sort_index()
    df = df.dropna()
    df = df.drop_duplicates()
    return df
print(os.listdir("data"))           # pour voir ce qu’il y a dans data/

# Lister tous les fichiers et dossiers dans le répertoire
for filename in os.listdir('data'):
    # Construire le chemin complet du fichier
    filepath = os.path.join('data', filename)
    print(filepath)

    # Vérifier si c'est un fichier et qu'il se termine par '.pkl'
    if os.path.isfile(filepath) and filename.endswith('.pkl'):
        print(f"\n--- Aperçu de '{filename}' 5 first elements")
        df = preprocess(pd.read_pickle(filepath))
        display(df.head(5))

print("-------------------------######################--------------------------------")
print(f"\n--- Aperçu de '{filename}' 5 first elements")
df = preprocess(pd.read_pickle('data/yfinance-STOXX50-1h.pkl'))
display(df.head(35))
# Out:
# ['binance-BTCUSD-1h.pkl', 'binance-DOGEEUR-1h.pkl', 'binance-ETHUSD-1h.pkl', 'yfinance-AAPL-1h.pkl', 'yfinance-CAC40-1h.pkl', 'yfinance-EURUSD-1h.pkl', 'yfinance-GOLDUSD-1h.pkl', 'yfinance-S&P500-1h.pkl', 'yfinance-STOXX50-1h.pkl']
# data\binance-BTCUSD-1h.pkl
#
# --- Aperçu de 'binance-BTCUSD-1h.pkl' 5 first elements
#                         open     high      low    close      volume  \
# date_open
# 2020-08-11 07:00:00  11785.0  11785.0  11735.0  11751.4    7.560836
# 2020-08-11 08:00:00  11752.2  11780.2  11711.9  11717.7  191.028616
# 2020-08-11 09:00:00  11718.9  11772.3  11704.2  11716.2  189.694611
# 2020-08-11 10:00:00  11708.9  11762.1  11656.3  11749.5  199.613807
# 2020-08-11 11:00:00  11750.2  11769.9  11725.0  11752.2  157.709769
#
#                              date_close
# date_open
# 2020-08-11 07:00:00 2020-08-11 08:00:00
# 2020-08-11 08:00:00 2020-08-11 09:00:00
# 2020-08-11 09:00:00 2020-08-11 10:00:00
# 2020-08-11 10:00:00 2020-08-11 11:00:00
# 2020-08-11 11:00:00 2020-08-11 12:00:00
# data\binance-DOGEEUR-1h.pkl
#
# --- Aperçu de 'binance-DOGEEUR-1h.pkl' 5 first elements
#                         open     high      low    close      volume  \
# date_open
# 2021-01-29 12:00:00  0.04684  0.19000  0.03900  0.05181  51358749.0
# 2021-01-29 13:00:00  0.05181  0.05699  0.04200  0.04413  47022463.7
# 2021-01-29 14:00:00  0.04423  0.04773  0.03853  0.04429  34717160.7
# 2021-01-29 15:00:00  0.04429  0.04995  0.04399  0.04548  25380511.1
# 2023-11-22 10:00:00       0 2023-11-22 11:00:00
# 2023-11-22 11:00:00       0 2023-11-22 12:00:00
# 2023-11-22 12:00:00       0 2023-11-22 13:00:00
# 2023-11-22 13:00:00       0 2023-11-22 14:00:00
# 2023-11-22 14:00:00       0 2023-11-22 15:00:00
# 2023-11-22 15:00:00       0 2023-11-22 16:00:00
# 2023-11-22 16:00:00       0 2023-11-22 17:00:00
# 2023-11-23 08:00:00       0 2023-11-23 09:00:00
# 2023-11-23 09:00:00       0 2023-11-23 10:00:00
# 2023-11-23 10:00:00       0 2023-11-23 11:00:00
# 2023-11-23 11:00:00       0 2023-11-23 12:00:00
# 2023-11-23 12:00:00       0 2023-11-23 13:00:00
# 2023-11-23 13:00:00       0 2023-11-23 14:00:00
# 2023-11-23 14:00:00       0 2023-11-23 15:00:00
# 2023-11-23 15:00:00       0 2023-11-23 16:00:00
# 2023-11-23 16:00:00       0 2023-11-23 17:00:00
# 2023-11-24 08:00:00       0 2023-11-24 09:00:00
# 2023-11-24 09:00:00       0 2023-11-24 10:00:00
# 2023-11-24 10:00:00       0 2023-11-24 11:00:00
# 2023-11-24 11:00:00       0 2023-11-24 12:00:00
# 2023-11-24 12:00:00       0 2023-11-24 13:00:00
# 2023-11-24 13:00:00       0 2023-11-24 14:00:00
# 2023-11-24 14:00:00       0 2023-11-24 15:00:00
# 2023-11-24 15:00:00       0 2023-11-24 16:00:00
# 2023-11-24 16:00:00       0 2023-11-24 17:00:00
# 2023-11-27 08:00:00       0 2023-11-27 09:00:00
# 2023-11-27 09:00:00       0 2023-11-27 10:00:00
# 2023-11-27 10:00:00       0 2023-11-27 11:00:00
# 2023-11-27 11:00:00       0 2023-11-27 12:00:00

# %% [markdown]
# ### Ajout de *features*
#
# Vous pouvez également rajouter de nouvelles données au DataFrame pour créer de nouvelles *features* que l'agent pourra utiliser.
# Voir pour cela la [doc](https://gym-trading-env.readthedocs.io/en/latest/features.html).
#
# Chaque nouvelle *feature* doit commencer par `feature_` pour être détectée.

# %%
def preprocess(df):
    df = df.sort_index()
    df = df.dropna()
    df = df.drop_duplicates()

    df['feature_close'] = (df['close'] - df['close'].mean()) / df['close'].std()

    # Ajout de nouvelles Features
    df['RSI'] = ta.momentum.RSIIndicator(df['close'], window=14).rsi()
    df['MACD'] = ta.trend.MACD(df['close']).macd()
    df['BB_High'] = ta.volatility.BollingerBands(df['close']).bollinger_hband()
    df['MA_20'] = df['close'].rolling(window=20).mean()
    #df['volume_norm'] = df['volume'] / df['volume'].rolling(window=50).mean()


    df = df.dropna()
    
    return df


for filename in os.listdir('data'):
    filepath = os.path.join('data', filename)

    if os.path.isfile(filepath) and filename.endswith('.pkl'):
        df = preprocess(pd.read_pickle(filepath))
        print(f"\n--- Aperçu de '{filename}' 5 first elements")
        display(df.head(5))
print("-------------------------######################--------------------------------")
print(f"\n--- Aperçu de '{filename}' 5 first elements")
df = preprocess(pd.read_pickle('data/yfinance-STOXX50-1h.pkl'))
display(df.head(5))
# Out:
# --- Aperçu de 'binance-BTCUSD-1h.pkl' 5 first elements
# 2023-11-24 15:00:00       0 2023-11-24 16:00:00      -2.119537  67.751121
#
#                          MACD      BB_High        MA_20
# date_open
# 2023-11-24 11:00:00  7.653318  4371.574365  4357.035986
# 2023-11-24 12:00:00  7.622091  4373.050683  4357.809497
# 2023-11-24 13:00:00  7.527512  4373.810115  4358.976489
# 2023-11-24 14:00:00  7.453789  4374.271900  4360.227002
# 2023-11-24 15:00:00  7.498557  4375.726729  4361.193506

# %% [markdown]
# Par défaut, l'agent ne reçoit comme *features* que sa dernière *position* (voir le paragraphe suivant), ce qui ne sera certainement pas suffisant ! À vous d'ajouter les *features* qui seront pertinentes pour que l'agent apprenne la politique optimale...

# %% [markdown]
# ## Fonctionnement des actions
#
# Une action est une **position**, c'est-à-dire un ratio entre la proportion d'*assets* (exemple : ETH) et la proportion de *fiat* (exemple : USD) dans le portefeuille.
# Ainsi, la position `0.5` consiste à avoir exactement 50% d'ETH et 50% d'USD (en vendant l'un ou l'autre pour arriver à ce ratio). `0.1` consiste à avoir 10% d'ETH et 90% d'USD.
#
# Il existe des positions un peu plus complexes :
#
# - `< 0` : une position inférieure à 0 va vendre encore plus d'ETH que le portefeuille n'en contient, pour obtenir des USD. Cela nécessite un emprunt, qui sera remboursé avec un intérêt.
# - `> 1` : une position supérieure à 1 va dépenser encore plus d'USD que le portefeuille n'en contient, pour acheter des ETH. Cela nécessite également un emprunt.
#
# Ces positions (qui sont appelées *short* et *margin* en finance) peuvent faire gagner beaucoup à votre agent, mais démultiplient les risques également. Si votre agent fait une bonne affaire, vous pouvez vendre à un prix élevé, racheter quand le prix est plus faible, et rembourser l'emprunt en empochant la différence. En revanche, si votre agent fait une mauvaise affaire, et doit vider son portefeuille pour rembourser l'emprunt, vous perdez automatiquement (`terminated=True`).
#
# ### Actions continues
#
# Par rapport à l'environnement `gym-trading-env` d'origine, la version que je vous fournis permet de spécifier directement une position comme action, c'est-à-dire un nombre flottant. Votre agent a donc un contrôle précis sur la position désirée. Cela rajoute de la flexibilité mais rend l'apprentissage beaucoup plus difficile.
#
# Exemple :

# %%
env = gym.make(
    "MultiDatasetTradingEnv",
    dataset_dir="data/*.pkl",
    preprocess=preprocess,
    portfolio_initial_value=1_000,
    trading_fees=0.1/100,
    borrow_interest_rate=0.02/100/24,
)

obs, _ = env.reset()
# On veut une position de 88% ETH / 12% USD
obs, reward, terminated, truncated, info = env.step(0.88)
print(obs)
print(info)
# Out:
# [-1.386383   0.88       0.8797828]
# {'idx': 1, 'step': 1, 'date': np.datetime64('2023-11-22T16:00:00.000000000'), 'position_index': None, 'position': 0.88, 'real_position': np.float64(0.8797827927810348), 'data_low': 1991.699951171875, 'data_BB_High': 2006.3928935459678, 'data_close': 1992.800048828125, 'data_MACD': -0.5557098747360669, 'data_open': 1996.9000244140625, 'data_high': 1997.5, 'data_date_close': Timestamp('2023-11-22 17:00:00'), 'data_volume': 25296, 'data_MA_20': 2000.7300048828124, 'data_RSI': 35.645615706392945, 'portfolio_valuation': np.float64(998.0840027016596), 'portfolio_distribution_asset': np.float64(0.440634840330975), 'portfolio_distribution_fiat': np.float64(119.98687137471966), 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': np.float64(-0.001917835169109476)}

# %% [markdown]
# Par défaut, l'espace des actions est limité à $[-1, 2]$ pour que votre agent ne puisse emprunter que jusqu'à 100%. Vous pouvez empêcher votre agent de prendre de telles positions, ou limiter le risque, en contrôlant les bornes autorisées des actions.
#
# Par exemple, en clippant l'action dans l'intervalle $[0,1]$, vous empêchez l'agent de faire des emprunts.
#
# À l'inverse, vous pouvez augmenter l'intervalle pour permettre des emprunts plus risqués, mais qui peuvent rapporter plus. À vous de choisir !
#
# Vous pouvez changer les bornes via le paramètre `position_range` du constructeur :

# %%
env = gym.make(
    "MultiDatasetTradingEnv",
    dataset_dir="data/*.pkl",
    preprocess=preprocess,
    position_range=(0, 1),  # ICI : (borne min, borne max)
    portfolio_initial_value=1_000,
    trading_fees=0.1/100,
    borrow_interest_rate=0.02/100/24,
)

# %% [markdown]
# Vous pouvez aussi modifier l'action en sortie de votre algorithme d'apprentissage, de la manière que vous souhaitez (clipping, interpolation, etc.).

# %% [markdown]
# ### Actions discrètes
#
# Pour simplifier l'apprentissage, vous pouvez utiliser le *wrapper* `gym_trading_env.wrapper.DiscreteActionsWrapper` que je vous fournis, et qui permet de revenir au fonctionnement d'origine de l'environnement `gym-trading-env`. Vous devrez alors spécifier l'ensemble des positions possibles, puis votre agent choisira une position parmi cette liste à chaque pas de temps.
# Par exemple, si la liste des positions est `[0, 0.5, 1]` et que l'action choisie est `1`, cela veut dire qu'on veut la position qui correspond au 2e élément de la liste, soit `0.5` (50%/50%).
#
# Vous pouvez rajouter autant d'actions que vous voulez, par exemple `[0, 0.25, 0.5, 1]` ou encore tous les 0.1 entre 0 et 1, etc. Plus il y a d'actions possibles, plus votre agent aura de choix (flexibilité), donc plus son comportement pourra être complexe, mais cela rajoute de la difficulté durant l'entraînement.
#
# N'oubliez pas que vous pouvez autoriser les positions avec emprunt en ajoutant des nombres inférieurs à 0 ou supérieurs à 1 à la liste autorisée.
#
# Exemple :

# %%
from gym_trading_env.wrapper import DiscreteActionsWrapper

# Vous pouvez aussi appeler le wrapper `env` pour faire plus simple
# Ici, je fais explicitement la distinction entre `wrapper` et `env`
wrapper = DiscreteActionsWrapper(env, positions=[-1, 0, 0.25, 0.5, 0.75, 1, 2])
obs, _ = wrapper.reset()
# On veut une position de 25% ETH / 75% USD ; cela correspond à la position
# d'index 2 dans la liste ci-dessus
obs, reward, terminated, truncated, info = wrapper.step(2)
print(obs)
print(info)
# Out:
# [-2.1305761   0.25        0.24996781]
# {'idx': 1, 'step': 1, 'date': np.datetime64('2023-11-24T12:00:00.000000000'), 'position_index': 2, 'position': 0.25, 'real_position': np.float64(0.2499678137560877), 'data_low': 4368.1298828125, 'data_BB_High': 4373.050682942275, 'data_close': 4368.5400390625, 'data_MACD': 7.622090587400635, 'data_open': 4369.4501953125, 'data_high': 4372.2099609375, 'data_date_close': Timestamp('2023-11-24 13:00:00'), 'data_volume': 0, 'data_MA_20': 4357.809497070312, 'data_RSI': 64.88733511477844, 'portfolio_valuation': np.float64(999.7170441550593), 'portfolio_distribution_asset': np.float64(0.0572037984469903), 'portfolio_distribution_fiat': np.float64(749.8199602529209), 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': np.float64(-0.0002829958844989802)}

# %% [markdown]
# Notez que, quand les actions continues sont utilisées, la variable `position_index` du dictionnaire `info` n'est pas disponible (c'est logique).

# %% [markdown]
# ## Changement de la fonction de récompense
#
# Vous pouvez changer la fonction de récompense pour améliorer l'apprentissage de l'agent.
# Dans tous les cas, vous serez évalué(e)s sur la valuation du portefeuille à la fin de l'épisode (voir [ci-dessous](#évaluation)), mais cette simple mesure n'est peut-être pas la meilleure fonction de récompense.
# D'autres fonctions peuvent encourager l'agent à mieux apprendre, en explorant diverses possibilités, etc.

# %%
"""
def reward_function(history):
    return history['portfolio_valuation', -1]
"""

def reward_function(history):
    # On récupère la valeur actuelle et la précédente
    current_val = history['portfolio_valuation', -1]
    prev_val = history['portfolio_valuation', -2]
    
    # Calcul du rendement logarithmique
    # C'est symétrique et ça s'additionne bien mathématiquement
    reward = np.log(current_val / prev_val)
    
    # (Optionnel) Pénalité de risque : Si on perd de l'argent, on punit plus fort 
    # pour apprendre la prudence (sorte de "Sortino Ratio" simplifié)
    # if reward < 0:
    #     reward *= 1.1 
    
    return reward

env = gym.make(
    "MultiDatasetTradingEnv",
    dataset_dir="data/*.pkl",
    preprocess=preprocess,
    portfolio_initial_value=1_000,
    trading_fees=0.1/100,
    borrow_interest_rate=0.02/100/24,
    # On spécifie la fonction de récompense
    reward_function=reward_function,
)

# %% [markdown]
# ## Déroulément d'un épisode
#
# Un épisode se déroule jusqu'à ce que :
#
# - l'agent atteigne la fin des données d'entraînement (nous n'avons plus de nouvelle donnée) => `truncated=True`
#
# - la valeur du portefeuille atteint 0 (l'agent a perdu tout l'argent) => `terminated=True`
#
# Vous devrez probablement entraîner l'agent sur plusieurs épisodes avant que son comportement ne converge.
#
# Pour éviter de sur-apprendre (*overfit*), vous devrez utiliser plusieurs jeux de données via [MultiDatasetTradingEnv](https://gym-trading-env.readthedocs.io/en/latest/multi_datasets.html).
#
# Dans ce cas, chaque épisode utilisera un jeu de données différent (en bouclant si vous demandez plus d'épisodes qu'il n'y a de jeux de données). Vous pouvez accéder au nom du jeu de données de l'épisode en cours via `env.name`.

# %%
"""
nb_episodes = 2
for episode in range(1, nb_episodes + 1):
    obs, _ = env.reset()
    print(f'Episode n˚{episode} -- Jeu de donnée {env.name}')
    done = False

    while not done:
        action = env.action_space.sample()
        obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

    if terminated:
        print('Argent perdu')
    elif truncated:
        print('Épisode terminé')
"""


from stable_baselines3 import PPO # Algorithme très performant et stable
from stable_baselines3.common.vec_env import DummyVecEnv

# Création de l'environnement avec la nouvelle reward function
env = gym.make(
    "MultiDatasetTradingEnv",
    dataset_dir="data/*.pkl",
    preprocess=preprocess,
    portfolio_initial_value=1_000,
    trading_fees=0.1/100,
    borrow_interest_rate=0.02/100/24,
    reward_function=reward_function, # Ta fonction optimisée
    # positions=[-1, 0, 1], # Si tu utilises le wrapper discret
)

# Création de l'agent  
model = PPO("MlpPolicy", env, verbose=1)
# Lancement de l'apprentissage
# L'agent va jouer des milliers d'épisodes tout seul pour maximiser la reward_function
print("Démarrage de l'entraînement...")
model.learn(total_timesteps=1_000_000) # 1 million de pas de temps (peut prendre du temps !)

# Sauvegarde de l'agent entrainé
model.save("mon_agent_trader")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Démarrage de l'entraînement...
# -----------------------------
# | time/              |      |
# |    fps             | 1460 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1003        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004907965 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.95       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00522     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00335    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0077      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003036817 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00344     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00339    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0033      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0030821252 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.575        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.011       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00213     |
# |    std                  | 1.02         |
# |    value_loss           | 0.00143      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0032293922 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0164      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00207     |
# |    std                  | 1.01         |
# |    value_loss           | 0.001        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 839          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0032682603 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0218      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.996        |
# |    value_loss           | 0.000539     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 7            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0023678986 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.363        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00492      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 1            |
# |    value_loss           | 0.000998     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007005917 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.197      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00551    |
# |    std                  | 0.992       |
# |    value_loss           | 0.000573    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003083637 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0221      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00489    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000979   |
# |    std                  | 0.983       |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004443486 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.00307     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0221     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00395    |
# |    std                  | 0.982       |
# |    value_loss           | 0.000346    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 11           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0035097962 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0817      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0116       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00188     |
# |    std                  | 0.98         |
# |    value_loss           | 0.000408     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 12           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0023207872 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.0144      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00646      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00271     |
# |    std                  | 0.964        |
# |    value_loss           | 0.000247     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 13           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0047119847 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.067       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0203      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00457     |
# |    std                  | 0.946        |
# |    value_loss           | 0.000188     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 14           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0056606336 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0145       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00823     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00366     |
# |    std                  | 0.945        |
# |    value_loss           | 0.000323     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 15          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004289558 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0185     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00304     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00144    |
# |    std                  | 0.947       |
# |    value_loss           | 0.00229     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 799          |
# |    iterations           | 16           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0016839288 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.014       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0118       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00079     |
# |    std                  | 0.942        |
# |    value_loss           | 0.000523     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 17           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0026415526 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0644       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00189      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000654    |
# |    std                  | 0.929        |
# |    value_loss           | 0.000528     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 18          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004087472 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0108      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00276    |
# |    std                  | 0.923       |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 19          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004068746 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00285    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00236    |
# |    std                  | 0.91        |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 20          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004557269 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00309    |
# |    std                  | 0.909       |
# |    value_loss           | 0.000723    |
# -----------------------------------------
# Market Return : 376.91%   |   Portfolio Return : -100.00%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.21e+04     |
# |    ep_rew_mean          | -34.5        |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 21           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0036956202 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.0905       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00607     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00256     |
# |    std                  | 0.899        |
# |    value_loss           | 0.000753     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.21e+04    |
# |    ep_rew_mean          | -34.5       |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 22          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005549142 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00325    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00219    |
# |    std                  | 0.883       |
# |    value_loss           | 0.00075     |
# -----------------------------------------
# Market Return :  9.40%   |   Portfolio Return : -94.04%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.33e+04     |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 23           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0063271914 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00339     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00444     |
# |    std                  | 0.866        |
# |    value_loss           | 0.000104     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.33e+04     |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 24           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0042519774 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00578     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00309     |
# |    std                  | 0.859        |
# |    value_loss           | 0.000175     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.33e+04     |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 25           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0056557134 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -0.00791     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0085      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00636     |
# |    std                  | 0.839        |
# |    value_loss           | 6e-05        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.33e+04     |
# |    ep_rew_mean          | -18.7        |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 26           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0045749303 |
# |    clip_fraction        | 0.0714       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.0554      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.01         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00728     |
# |    std                  | 0.828        |
# |    value_loss           | 7.81e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33e+04    |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 27          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007530016 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.258      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.829       |
# |    value_loss           | 4.95e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33e+04    |
# |    ep_rew_mean          | -18.7       |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 28          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007119928 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00122     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00477    |
# |    std                  | 0.816       |
# |    value_loss           | 7.63e-05    |
# -----------------------------------------
# Market Return : 103.53%   |   Portfolio Return : -99.27%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 29           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0076556397 |
# |    clip_fraction        | 0.0906       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0128      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00756     |
# |    std                  | 0.8          |
# |    value_loss           | 3.74e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+04    |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 780         |
# |    iterations           | 30          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.002009481 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0018      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.000345    |
# |    std                  | 0.789       |
# |    value_loss           | 0.000382    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 782          |
# |    iterations           | 31           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0026684466 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.00283     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00427      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000312     |
# |    std                  | 0.785        |
# |    value_loss           | 0.00118      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+04    |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 32          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004449188 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.0756      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0112     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00218    |
# |    std                  | 0.77        |
# |    value_loss           | 0.00265     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 33           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0044204304 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00265     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00098     |
# |    std                  | 0.774        |
# |    value_loss           | 0.00225      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 34           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0047361897 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00992      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000537    |
# |    std                  | 0.752        |
# |    value_loss           | 0.00148      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 35           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0035541728 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00335     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00134     |
# |    std                  | 0.738        |
# |    value_loss           | 0.000578     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+04    |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 36          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003017983 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0666      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00864    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000707   |
# |    std                  | 0.73        |
# |    value_loss           | 0.00119     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+04    |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 37          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003707673 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0532      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00146     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 3.98e-05    |
# |    std                  | 0.73        |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 38           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0016220335 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0891       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0119       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 3.56e-05     |
# |    std                  | 0.726        |
# |    value_loss           | 0.00194      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 39           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0013232006 |
# |    clip_fraction        | 0.00698      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00392     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000173    |
# |    std                  | 0.712        |
# |    value_loss           | 0.000847     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 40           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0034895125 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000979    |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.000393     |
# |    std                  | 0.71         |
# |    value_loss           | 0.000612     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.94e+04  |
# |    ep_rew_mean          | -14.1     |
# | time/                   |           |
# |    fps                  | 788       |
# |    iterations           | 41        |
# |    time_elapsed         | 106       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0049295 |
# |    clip_fraction        | 0.0215    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.07     |
# |    explained_variance   | 0.299     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00566   |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.000372 |
# |    std                  | 0.702     |
# |    value_loss           | 0.000949  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 42           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0036336258 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00789      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000814    |
# |    std                  | 0.694        |
# |    value_loss           | 0.00034      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 43           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0037137507 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.015        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000641     |
# |    std                  | 0.688        |
# |    value_loss           | 0.000272     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 44           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0026756544 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00179     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.698        |
# |    value_loss           | 0.000498     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+04    |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 45          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007255419 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0032     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00433    |
# |    std                  | 0.687       |
# |    value_loss           | 0.000487    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 46           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0058538946 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.0881      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0111      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.684        |
# |    value_loss           | 0.000257     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.94e+04   |
# |    ep_rew_mean          | -14.1      |
# | time/                   |            |
# |    fps                  | 793        |
# |    iterations           | 47         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00406985 |
# |    clip_fraction        | 0.0354     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | -0.102     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.82e-05   |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 5.22e-05   |
# |    std                  | 0.685      |
# |    value_loss           | 0.000331   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+04    |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 48          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007953964 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00357    |
# |    std                  | 0.672       |
# |    value_loss           | 0.000228    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 49           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0024877912 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.0314       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00321     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000263    |
# |    std                  | 0.673        |
# |    value_loss           | 0.000367     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+04     |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 50           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0013446473 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000217     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000137    |
# |    std                  | 0.675        |
# |    value_loss           | 0.000143     |
# ------------------------------------------
# Market Return : 699.62%   |   Portfolio Return : -99.99%   |
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.61e+04      |
# |    ep_rew_mean          | -12.9         |
# | time/                   |               |
# |    fps                  | 792           |
# |    iterations           | 51            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00068460347 |
# |    clip_fraction        | 0.0194        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | 0.337         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00289      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.00039      |
# |    std                  | 0.68          |
# |    value_loss           | 0.000118      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.61e+04     |
# |    ep_rew_mean          | -12.9        |
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 52           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0024893496 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00236      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.000411     |
# |    std                  | 0.679        |
# |    value_loss           | 0.000147     |
# ------------------------------------------
# Market Return : 39.77%   |   Portfolio Return : -24.13%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.16e+04     |
# |    ep_rew_mean          | -10.3        |
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 53           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0026558193 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00443     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.665        |
# |    value_loss           | 0.000553     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16e+04    |
# |    ep_rew_mean          | -10.3       |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 54          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005379742 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0196     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 0.656       |
# |    value_loss           | 0.000479    |
# -----------------------------------------
# Market Return : 43.37%   |   Portfolio Return : -27.26%   |
# ------------------------------------------
# ...
# |    ep_rew_mean          | -0.69        |
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 473          |
# |    time_elapsed         | 2367         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0038116323 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.386        |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00134     |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | 0.0016       |
# |    std                  | 0.164        |
# |    value_loss           | 0.00171      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+04    |
# |    ep_rew_mean          | -0.69       |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 474         |
# |    time_elapsed         | 2369        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.004516522 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.385       |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | 0.00185     |
# |    std                  | 0.166       |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | -0.69        |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 475          |
# |    time_elapsed         | 2372         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0047502015 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.379        |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00707      |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | 0.000716     |
# |    std                  | 0.165        |
# |    value_loss           | 7.05e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+04    |
# |    ep_rew_mean          | -0.69       |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 476         |
# |    time_elapsed         | 2374        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.004453119 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.384       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00512    |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | 0.00285     |
# |    std                  | 0.165       |
# |    value_loss           | 8.06e-06    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -0.69      |
# | time/                   |            |
# |    fps                  | 410        |
# |    iterations           | 477        |
# |    time_elapsed         | 2377       |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.00408464 |
# |    clip_fraction        | 0.0576     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.387      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00657    |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | 0.00248    |
# |    std                  | 0.164      |
# |    value_loss           | 3.08e-05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | -0.69        |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 478          |
# |    time_elapsed         | 2379         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0021199428 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.398        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0244      |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | 0.00211      |
# |    std                  | 0.161        |
# |    value_loss           | 3.29e-05     |
# ------------------------------------------
# Market Return :  5.93%   |   Portfolio Return :  3.06%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | -0.683       |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 479          |
# |    time_elapsed         | 2381         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0037110471 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.401        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00488     |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.163        |
# |    value_loss           | 5.5e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | -0.683       |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 480          |
# |    time_elapsed         | 2384         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0033102068 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.394        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00429      |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | 0.00195      |
# |    std                  | 0.164        |
# |    value_loss           | 2.4e-05      |
# ------------------------------------------
# Market Return : 43.37%   |   Portfolio Return : 58.14%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | -0.671       |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 481          |
# |    time_elapsed         | 2387         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0041711824 |
# |    clip_fraction        | 0.063        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.386        |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00306      |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 0.00162      |
# |    std                  | 0.165        |
# |    value_loss           | 0.000147     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+04     |
# |    ep_rew_mean          | -0.671       |
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 482          |
# |    time_elapsed         | 2389         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0033743007 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.382        |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0182       |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | 0.000744     |
# |    std                  | 0.165        |
# |    value_loss           | 0.000367     |
# ------------------------------------------
# Market Return : 39.77%   |   Portfolio Return : 21.64%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04e+04     |
# |    ep_rew_mean          | -0.661       |
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 483          |
# |    time_elapsed         | 2391         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0027651642 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.391        |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00118      |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | 0.00151      |
# |    std                  | 0.163        |
# |    value_loss           | 0.000606     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04e+04     |
# |    ep_rew_mean          | -0.661       |
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 484          |
# |    time_elapsed         | 2394         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0013507111 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.404        |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0109       |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | 0.00118      |
# |    std                  | 0.161        |
# |    value_loss           | 0.000133     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+04    |
# |    ep_rew_mean          | -0.661      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 485         |
# |    time_elapsed         | 2397        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.004152623 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.408       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00222    |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | 0.000379    |
# |    std                  | 0.161       |
# |    value_loss           | 0.000123    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+04    |
# |    ep_rew_mean          | -0.661      |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 486         |
# |    time_elapsed         | 2798        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.005265906 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.412       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0149      |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | 0.000336    |
# |    std                  | 0.16        |
# |    value_loss           | 0.00011     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+04    |
# |    ep_rew_mean          | -0.661      |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 487         |
# |    time_elapsed         | 2801        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.003759888 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.412       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00498    |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -4.36e-05   |
# |    std                  | 0.16        |
# |    value_loss           | 5.68e-05    |
# -----------------------------------------
# Market Return : 103.53%   |   Portfolio Return :  2.98%   |
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+04    |
# |    ep_rew_mean          | -0.654      |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 488         |
# |    time_elapsed         | 2804        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.009275344 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.415       |
# |    explained_variance   | -0.057      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00182     |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | 0.000297    |
# |    std                  | 0.159       |
# |    value_loss           | 0.00015     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+04   |
# |    ep_rew_mean          | -0.654     |
# | time/                   |            |
# |    fps                  | 356        |
# |    iterations           | 489        |
# |    time_elapsed         | 2806       |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.00814288 |
# |    clip_fraction        | 0.0745     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.426      |
# |    explained_variance   | 0.745      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.018     |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | 0.00221    |
# |    std                  | 0.157      |
# |    value_loss           | 0.000375   |
# ----------------------------------------

# %%
# Recharger l'agent entraîné
model = PPO.load("mon_agent_trader")

# Créer un environnement de test (propre)
env_eval = gym.make(
    "MultiDatasetTradingEnv",
    dataset_dir="data/*.pkl", # Idéalement, utilise des données de test séparées ici !
    preprocess=preprocess,
    portfolio_initial_value=1_000,
    trading_fees=0.1/100,
    borrow_interest_rate=0.02/100/24,
)

# Boucle d'évaluation sur tous les datasets
final_valuations = []
nb_datasets = len(os.listdir("data"))
 # Nombre de fichiers pkl que tu as

for i in range(nb_datasets):
    obs, _ = env_eval.reset()
    done = False
    
    while not done:
        # L'agent prédit l'action optimale cette fois (pas de sample aléatoire)
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env_eval.step(action)
        done = terminated or truncated
    
    final_val = info['portfolio_valuation']
    print(f"Dataset {i+1} - Valeur Finale : {final_val:.2f}$")
    final_valuations.append(final_val)

print(f"--- Moyenne Globale : {sum(final_valuations)/len(final_valuations):.2f}$ ---")
# Out:
# Market Return : 1029.16%   |   Portfolio Return : -241.85%   |
# Dataset 1 - Valeur Finale : -1418.53$
# Market Return : 103.53%   |   Portfolio Return :  8.08%   |
# Dataset 2 - Valeur Finale : 1080.84$
# Market Return :  9.40%   |   Portfolio Return : 59.45%   |
# Dataset 3 - Valeur Finale : 1594.47$
# Market Return : 26.58%   |   Portfolio Return : 67.48%   |
# Dataset 4 - Valeur Finale : 1674.79$
# Market Return :  5.93%   |   Portfolio Return : 11.73%   |
# Dataset 5 - Valeur Finale : 1117.35$
# Market Return : 43.37%   |   Portfolio Return : 77.52%   |
# Dataset 6 - Valeur Finale : 1775.21$
# Market Return : 814.18%   |   Portfolio Return : -103.98%   |
# Dataset 7 - Valeur Finale : -39.79$
# Market Return : 39.77%   |   Portfolio Return : 40.23%   |
# Dataset 8 - Valeur Finale : 1402.35$
# Market Return : 1029.16%   |   Portfolio Return : -241.96%   |
# Dataset 9 - Valeur Finale : -1419.59$
# --- Moyenne Globale : 640.79$ ---

# %% [markdown]
# ## Évaluation
#
# Afin de disposer d'un critère simple pour comparer les différentes solutions, nous utiliserons la valeur du portefeuille (`portfolio_valuation`).
# C'est assez simple : on veut que l'agent ait gagné le plus d'argent à la fin de la simulation.
#
# Vous pouvez ajouter ce critère à la liste des métriques affichées à la fin de chaque épisode, pour que ce soit plus visible :

# %%
def metric_portfolio_valuation(history):
    return round(history['portfolio_valuation', -1], 2)

env.add_metric('Portfolio Valuation', metric_portfolio_valuation)

done = False
obs, _ = env.reset()

while not done:
    action = env.action_space.sample()
    obs, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
# Out:
# Market Return : 699.62%   |   Portfolio Return : -100.00%   |   Portfolio Valuation : 0.0   |

# %% [markdown]
# Puisque l'environnement peut se dérouler sur plusieurs épisodes (1 par jeu de données), vous devrez calculer la **moyenne des `portfolio_valuation`** sur l'ensemble des jeux de données possibles.

# %% [markdown]
# ⚠️ Pour que ce soit honnête, vous **devez initialiser l'environnement avec les contraintes** imposées dans le sujet :
#
# - une valeur initiale du portefeuille de `1000` ;
# - des frais de 0.1% par transaction ;
# - un taux d'intérêt de 0.02% par jour soit 0.02/100/24 par heure.
#
# Sinon, il est beaucoup plus simple d'augmenter la valeur finale...
#
# ```py
# env = gym.make(
#     "MultiDatasetTradingEnv",
#     dataset_dir="data/*.pkl",
#     preprocess=preprocess,
#     # LIGNES SUIVANTES :
#     # Valeur initiale du portefeuille
#     portfolio_initial_value=1_000,
#     # Frais de transactions
#     trading_fees=0.1/100,
#     # Intérêts sur les prêts
#     borrow_interest_rate=0.02/100/24,
# )
# ```
#
# Vous pouvez également accéder à la métrique de `portfolio_valuation` à la fin d'une simulation, si vous voulez par exemple l'ajouter à votre *run* WandB :

# %%
portfolio_valuation = env.historical_info['portfolio_valuation', -1]
# Si on avait WandB :
# run.summary['portfolio_valuation'] = portfolio_valuation
# On simule ça par un simple print...
print(portfolio_valuation)
# Out:
# 7.906996735710066e-17

# %% [markdown]
# Ou bien, pour récupérer les métriques calculées par l'environnement (cela peut être utile pour les ajouter à WandB) :

# %%
metrics = env.get_metrics()
print(metrics)
portfolio_valuation = metrics['Portfolio Valuation']
print(portfolio_valuation)
# Out:
# {'Market Return': '699.62%', 'Portfolio Return': '-100.00%', 'Portfolio Valuation': np.float64(0.0)}
# 0.0

# %% [markdown]
# ## Conseils
#
# À part les quelques contraintes présentées dans ce fichier (et rappelées sur la page du projet), vous êtes assez libres !
#
# Votre algorithme de RL peut être arbitrairement simple ou complexe. Je liste ici quelques conseils ou pistes, que vous pouvez explorer :
#
# - *Features* : Par défaut, votre agent n'utilise que le prix de l'*asset* (`close`) comme *feature* pour la prise de décision. Vous pouvez ajouter les *features* que vous voulez. En particulier, des métriques spécifiques à la finance peuvent être intéressantes, par exemple pour déterminer le risque que le prix change brutalement (à la hausse ou à la baisse)...
#
# - Algorithme : Vous pouvez utiliser des algorithmes existants, ou en inventer un nouveau. N'hésitez pas à ré-utiliser tout ce que vous avez appris en *Machine Learning* et *Deep Learning*. Typiquement, les données financières sont des données temporelles : certains réseaux de neurones sont plus appropriés que d'autres pour ce genre de tâche...
#
# - Configuration de l'environnement : L'environnement est très extensible ! Vous pouvez par exemple ajouter des *features* dynamiques (pas seulement calculées lors du prétraitement). La [documentation](https://gym-trading-env.readthedocs.io/en/latest/index.html) est très claire et très complète.
#
# Vous pouvez vous inspirer de travaux existants trouvés sur l'Internet à condition de **citer votre source**. Utiliser le travail de quelqu'un d'autre sans le citer sera considéré comme du plagiat.
